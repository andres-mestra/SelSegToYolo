# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Lee el archivo CSV
data = pd.read_csv('data/runs/detect/train/results.csv')
(data)
# Out:
#                       epoch           train/box_loss           train/cls_loss  \
# 0                         1                  1.41460                  2.26940
# 1                         2                  1.50550                  2.04120
# 2                         3                  1.63340                  2.09020
# 3                         4                  1.64750                  2.03340
# 4                         5                  1.63520                  2.02850
# 5                         6                  1.54630                  1.84350
# 6                         7                  1.51210                  1.74250
# 7                         8                  1.56350                  1.66180
# 8                         9                  1.47050                  1.76440
# 9                        10                  1.42750                  1.74730
# 10                       11                  1.47510                  1.71310
# ...

# %%
# Extrae las columnas relevantes
# columns = ['epoch','train/box_loss','train/cls_loss','train/dfl_loss','metrics/precision(B)','metrics/recall(B)','val/box_loss','val/cls_loss','val/dfl_loss']
# data = data[columns]
